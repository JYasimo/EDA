# %%
#import essential libraries
import pandas as pd
import missingno as msno
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
#read csv file from google drive
df=pd.read_csv("/Users/yasamanmohammadi/Documents/UTS/Semester 2/Statistical Thinking for Data Science/AT3_STDS/TeleCom_Data-1.csv")

# %% [markdown]
# # Data Cleaning

# %%
# convert target column to 0 and 1
df['y'] = df['y'].str.lower()
y_mapping = {
    'yes': 1,
    'no': 0
}
df['y'] = df['y'].map(y_mapping)

# %%
import pandas as pd


# Iterate through each column and print the count of NaN values
for column in df.columns:
    nan_count = df[column].isna().sum()
    print(f"Column '{column}' has {nan_count} NaN values.")
# Out:
# Column 'age' has 0 NaN values.
# Column 'job' has 0 NaN values.
# Column 'marital' has 0 NaN values.
# Column 'education' has 0 NaN values.
# Column 'default' has 0 NaN values.
# Column 'housing' has 0 NaN values.
# Column 'loan' has 0 NaN values.
# Column 'contact' has 0 NaN values.
# Column 'month' has 0 NaN values.
# Column 'day_of_week' has 0 NaN values.
# Column 'duration' has 0 NaN values.
# Column 'campaign' has 0 NaN values.
# Column 'pdays' has 0 NaN values.
# Column 'previous' has 0 NaN values.
# Column 'poutcome' has 0 NaN values.
# Column 'emp.var.rate' has 0 NaN values.
# Column 'cons.price.idx' has 0 NaN values.
# Column 'cons.conf.idx' has 0 NaN values.
# Column 'euribor3m' has 0 NaN values.
# Column 'nr.employed' has 0 NaN values.
# Column 'y' has 0 NaN values.

# %%
# Count duplicate rows based on all columns
duplicate_count = df.duplicated().sum()

print(f"Total duplicate rows: {duplicate_count}")
# Out:
# Total duplicate rows: 12

# %%
# Remove duplicate rows based on all columns
df = df.drop_duplicates()

# %% [markdown]
# # Numerical columns

# %%
#finding numerical columns
df_num= df.select_dtypes(include=np.number)
df_num[df_num.columns]
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       40       151         1    999         0           1.1          93.994
# 1       56       307         1    999         0           1.1          93.994
# 2       45       198         1    999         0           1.1          93.994
# 3       59       139         1    999         0           1.1          93.994
# 4       41       217         1    999         0           1.1          93.994
# ...    ...       ...       ...    ...       ...           ...             ...
# 41175   29       112         1      9         1          -1.1          94.767
# 41176   73       334         1    999         0          -1.1          94.767
# 41177   46       383         1    999         0          -1.1          94.767
# 41178   56       189         2    999         0          -1.1          94.767
# 41179   44       442         1    999         0          -1.1          94.767
#
# ...

# %% [markdown]
# # Categorical columns

# %%
#Identifying variables of the object type
totalcat=df.select_dtypes(include=['object'])
totalcat.head()
# Out:
#            job  marital            education  default housing loan    contact  \
# 0       admin.  married             basic.6y       no      no   no  telephone
# 1     services  married          high.school       no      no  yes  telephone
# 2     services  married             basic.9y  unknown      no   no  telephone
# 3       admin.  married  professional.course       no      no   no  telephone
# 4  blue-collar  married              unknown  unknown      no   no  telephone
#
#   month day_of_week     poutcome
# 0   may         mon  nonexistent
# 1   may         mon  nonexistent
# 2   may         mon  nonexistent
# 3   may         mon  nonexistent
# 4   may         mon  nonexistent

# %%
# Unique marital values
unique_marital_values = df['marital'].unique()
print('Unique marital values:', unique_marital_values)


print('                                                                                                  ')
print('**************************************************************************************************')
print('                                                                                                  ')

# Unique job values
unique_job_values = df['job'].unique()
print('Unique job values:', unique_job_values)

print('                                                                                                  ')
print('**************************************************************************************************')
print('                                                                                                  ')

# Unique education values
unique_education_values = df['education'].unique()
print('Unique education values:', unique_education_values)

print('                                                                                                  ')
print('**************************************************************************************************')
print('                                                                                                  ')

# Unique default values
unique_default_values = df['default'].unique()
print('Unique default values:', unique_default_values)

print('                                                                                                  ')
print('**************************************************************************************************')
print('                                                                                                  ')

# Unique housing values
unique_housing_values = df['housing'].unique()
print('Unique housing values:', unique_housing_values)

print('                                                                                                  ')
print('**************************************************************************************************')
print('                                                                                                  ')

# Unique loan values
unique_loan_values = df['loan'].unique()
print('Unique loan values:', unique_loan_values)

print('                                                                                                  ')
print('**************************************************************************************************')
print('                                                                                                  ')

# Unique contact values
unique_contact_values = df['contact'].unique()
print('Unique contact values:', unique_contact_values)

print('                                                                                                  ')
print('**************************************************************************************************')
print('                                                                                                  ')

# Unique day of week values
unique_day_of_week_values = df['day_of_week'].unique()
print('Unique day of week values:', unique_day_of_week_values)

print('                                                                                                  ')
print('**************************************************************************************************')
print('                                                                                                  ')

# Unique poutcome values
unique_poutcome_values = df['poutcome'].unique()
print('Unique poutcome values:', unique_poutcome_values)

print('                                                                                                  ')
print('**************************************************************************************************')
print('                                                                                                  ')
# Unique month values
unique_month_values = df['month'].unique()
print('Unique month values:', unique_month_values)

print('                                                                                                  ')
print('**************************************************************************************************')
print('                                                                                                  ')
# Unique month values
unique_y_values = df['y'].unique()
print('Unique y values:', unique_y_values)
# Out:
# Unique marital values: ['married' 'single' 'divorced' 'unknown']
#
# **************************************************************************************************
#
# Unique job values: ['admin.' 'services' 'blue-collar' 'technician' 'housemaid' 'retired'
#  'management' 'unemployed' 'self-employed' 'unknown' 'entrepreneur'
#  'student']
#
# **************************************************************************************************
#
# Unique education values: ['basic.6y' 'high.school' 'basic.9y' 'professional.course' 'unknown'
#  'basic.4y' 'university.degree' 'illiterate']
#
# **************************************************************************************************
#
# Unique default values: ['no' 'unknown' 'yes']
#
# **************************************************************************************************
#
# Unique housing values: ['no' 'yes' 'unknown']
#
# ...

# %% [markdown]
# # Feature Engineering

# %%
#########################
###label encoding week###
#########################



# Define the mapping of weekday names to integers
weekday_mapping = {'mon': 0, 'tue': 1, 'wed': 2, 'thu': 3, 'fri': 4}

# Create a custom label encoder using the mapping
df['day_of_week_encoded'] = df['day_of_week'].map(weekday_mapping)


##############################
###label encoding education###
##############################

# Define a custom mapping of education levels to integers with a specified order
education_mapping = {
    'unknown': 0,
    'illiterate': 1,
    'basic.4y': 2,
    'basic.6y': 3,
    'basic.9y': 4,
    'high.school': 5,
    'professional.course': 6,
    'university.degree': 7
}

# Create a custom label encoder using the mapping
df['education_encoded'] = df['education'].map(education_mapping)

##############################
###label encoding month#######
##############################

# Define a custom mapping for label encoding
month_mapping = {
    'jan': 0,
    'feb': 1,
    'mar': 2,
    'apr': 3,
    'may': 4,
    'jun': 5,
    'jul': 6,
    'aug': 7,
    'sep': 8,
    'oct': 9,
    'nov': 10,
    'dec': 11
}

# Perform label encoding based on the custom mapping
df['month_encoded'] = df['month'].map(month_mapping)

# Drop label encoded columns
columns_to_drop = ['month', 'day_of_week', 'education']
df.drop(columns=columns_to_drop, inplace=True)



#df head
df.head()
# Out:
#    age          job  marital  default housing loan    contact  duration  \
# 0   40       admin.  married       no      no   no  telephone       151
# 1   56     services  married       no      no  yes  telephone       307
# 2   45     services  married  unknown      no   no  telephone       198
# 3   59       admin.  married       no      no   no  telephone       139
# 4   41  blue-collar  married  unknown      no   no  telephone       217
#
#    campaign  pdays  ...     poutcome emp.var.rate  cons.price.idx  \
# 0         1    999  ...  nonexistent          1.1          93.994
# 1         1    999  ...  nonexistent          1.1          93.994
# 2         1    999  ...  nonexistent          1.1          93.994
# 3         1    999  ...  nonexistent          1.1          93.994
# 4         1    999  ...  nonexistent          1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed  y  day_of_week_encoded  \
# 0          -36.4      4.857       5191.0  0                    0
# ...

# %%
########################
###One_Hot_encoding#####
########################

# Columns to one-hot encode with custom prefixes
columns_to_encode = ['marital', 'job', 'default', 'housing', 'loan', 'contact','poutcome']

# Perform one-hot encoding for each specified column with custom prefixes
for column in columns_to_encode:
    df = pd.get_dummies(df, columns=[column], prefix=column, prefix_sep='_')

# %% [markdown]
# # Splitting The Dataset (for the feature engineered df)

# %%
#indicating x and y columns
y= df["y"]
x= df.drop(["y"],axis=1)

# %%
#Split the dataset into 2 different sets: train (80%) and test (20%)
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %% [markdown]
# # Models  (feature engineered dataframe)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier



# Initialize classifiers
classifiers = {
    'KNN': KNeighborsClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'GBM': GradientBoostingClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Logistic Regression': LogisticRegression()
    
}

results = []  # Initialize the results list outside of the loop

for name, clf in classifiers.items():
    # Train the classifier on the training set
    clf.fit(X_train, y_train)

    # Make predictions on both the training and testing sets
    y_train_pred = clf.predict(X_train)
    y_test_pred = clf.predict(X_test)
    y_train_prob = clf.predict_proba(X_train)[:, 1]  # Probability of positive class for training set
    y_test_prob = clf.predict_proba(X_test)[:, 1]  # Probability of positive class for testing set

    # Calculate evaluation metrics for training set
    accuracy_train = accuracy_score(y_train, y_train_pred)
    precision_train = precision_score(y_train, y_train_pred)
    recall_train = recall_score(y_train, y_train_pred)
    f1_train = f1_score(y_train, y_train_pred)
    auc_train = roc_auc_score(y_train, y_train_prob)
    cross_entropy_train = log_loss(y_train, y_train_prob)
    
    # Calculate evaluation metrics for testing set
    accuracy_test = accuracy_score(y_test, y_test_pred)
    precision_test = precision_score(y_test, y_test_pred)
    recall_test = recall_score(y_test, y_test_pred)
    f1_test = f1_score(y_test, y_test_pred)
    auc_test = roc_auc_score(y_test, y_test_prob)
    cross_entropy_test = log_loss(y_test, y_test_prob)

    # Initialize specificity_train to a default value
    specificity_train = 0.0

    # Calculate specificity for testing set
    tn, fp, fn, tp = confusion_matrix(y_test, y_test_pred).ravel()
    specificity_test = tn / (tn + fp)



    # Calculate sensitivity for training and testing sets
    sensitivity_train = recall_score(y_train, y_train_pred)
    sensitivity_test = recall_score(y_test, y_test_pred)

    # Append the results to the list
    results.append([name, 
                sensitivity_train, sensitivity_test, 
                f1_test, f1_train, 
                precision_test, precision_train, 
                auc_test, auc_train, 
                cross_entropy_test, cross_entropy_train])



# Create a table with the results
result_table = pd.DataFrame(results, columns=["Classifier", 
                                              "Sensitivity Test", "Sensitivity Train",
                                              "f1 Test", "f1 Train",
                                              "Precision Test", "Precision Train",
                                              "AUC Test", "AUC Train",
                                              "Cross-Entropy Test", "Cross-Entropy Train"])

result_table.head()
# Out:
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#             Classifier  Sensitivity Test  Sensitivity Train   f1 Test  \
# 0                  KNN          0.606289           0.475983  0.529769
# 1        Decision Tree          1.000000           0.532751  0.515584
# 2                  GBM          0.543671           0.527293  0.586521
# 3        Random Forest          1.000000           0.500000  0.563346
# 4  Logistic Regression          0.384037           0.412664  0.513936
#
# ...

# %%
# Initialize classifiers
classifiers = {
        'KNN': KNeighborsClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'GBM': GradientBoostingClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Logistic Regression': LogisticRegression()
    
}

results = []  # Initialize the results list outside of the loop

for name, clf in classifiers.items():
    # Train the classifier on the training set
    clf.fit(X_train, y_train)

    # Make predictions on both the training and testing sets
    y_train_pred = clf.predict(X_train)
    y_test_pred = clf.predict(X_test)
    y_train_prob = clf.predict_proba(X_train)[:, 1]  # Probability of positive class for training set
    y_test_prob = clf.predict_proba(X_test)[:, 1]  # Probability of positive class for testing set

    # Calculate evaluation metrics for training set
    accuracy_train = accuracy_score(y_train, y_train_pred)
    precision_train = precision_score(y_train, y_train_pred)
    recall_train = recall_score(y_train, y_train_pred)
    f1_train = f1_score(y_train, y_train_pred)
    auc_train = roc_auc_score(y_train, y_train_prob)
    cross_entropy_train = log_loss(y_train, y_train_prob)
    
    # Calculate evaluation metrics for testing set
    accuracy_test = accuracy_score(y_test, y_test_pred)
    precision_test = precision_score(y_test, y_test_pred)
    recall_test = recall_score(y_test, y_test_pred)
    f1_test = f1_score(y_test, y_test_pred)
    auc_test = roc_auc_score(y_test, y_test_prob)
    cross_entropy_test = log_loss(y_test, y_test_prob)

    # Initialize specificity_train to a default value
    specificity_train = 0.0

    # Calculate specificity for testing set
    tn, fp, fn, tp = confusion_matrix(y_test, y_test_pred).ravel()
    specificity_test = tn / (tn + fp)



    # Calculate sensitivity for training and testing sets
    sensitivity_train = recall_score(y_train, y_train_pred)
    sensitivity_test = recall_score(y_test, y_test_pred)

    # Append the results to the list
    results.append([name, 
                f1_test, f1_train])



# Create a table with the results
result_table2 = pd.DataFrame(results, columns=["Classifier", "f1 Test", "f1 Train"])
                                        

result_table2.head()
# Out:
#             Classifier   f1 Test  f1 Train
# 0                  KNN  0.548810  0.680041
# 1        Decision Tree  0.490185  0.967599
# 2                  GBM  0.599639  0.607881
# 3        Random Forest  0.545351  0.967777
# 4  Logistic Regression  0.509165  0.487341

# %% [markdown]
# # Using Bayesian to search for optimal hyperparameters for a Logistic Regression Model

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score  # Import the f1_score function
from sklearn.linear_model import LogisticRegression
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler

# Define the number of folds for cross-validation
n_folds = 5

# Initialize lists to store the estimated parameters and validation scores from each fold
params = []
params_intervals = []
train_f1_scores = []  # Change from train_auroc_scores to train_f1_scores
test_f1_scores = []   # Change from test_auroc_scores to test_f1_scores

# Perform cross-validation
kf = KFold(n_splits=n_folds)
for train_index, test_index in kf.split(df):
    # Reset the indices to ensure they are continuous
    train = df.iloc[train_index, :].reset_index(drop=True).copy()
    test = df.iloc[test_index, :].reset_index(drop=True).copy()

    response = 'y'  # the target is y
    predictors = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
       'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
       'day_of_week_encoded', 'education_encoded', 'month_encoded',
       'marital_divorced', 'marital_married', 'marital_single',
       'marital_unknown', 'job_admin.', 'job_blue-collar', 'job_entrepreneur',
       'job_housemaid', 'job_management', 'job_retired', 'job_self-employed',
       'job_services', 'job_student', 'job_technician', 'job_unemployed',
       'job_unknown', 'default_no', 'default_unknown', 'default_yes',
       'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
       'loan_unknown', 'loan_yes', 'contact_cellular', 'contact_telephone',
       'poutcome_failure', 'poutcome_nonexistent', 'poutcome_success']  # Replace with your predictor columns

    scaler = StandardScaler()

    X_train = scaler.fit_transform(train[predictors])
    X_test = scaler.transform(test[predictors])

    y_train = train[response]
    y_test = test[response]

    # Define the logistic regression model
    logistic_reg = LogisticRegression()

    # Define the hyperparameter space for Bayesian optimization
    param_space = {
        'penalty': ['none', 'l2']
    }

    # Use Bayesian optimization to find the optimal hyperparameters
    opt = BayesSearchCV(logistic_reg, param_space, n_iter=50, cv=5)
    opt.fit(X_train, y_train)

    # Get the best hyperparameters
    best_params = opt.best_params_

    # Train the logistic regression model with the best hyperparameters
    logistic_reg = LogisticRegression(**best_params)
    logistic_reg.fit(X_train, y_train)

    # Generate predictions for the training and test sets
    y_train_pred = logistic_reg.predict(X_train)
    y_test_pred = logistic_reg.predict(X_test)

    # Compute the F1 scores for training and test sets
    train_f1 = f1_score(y_train, y_train_pred)  # Use F1 score instead of AUROC
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1_scores.append(train_f1)
    test_f1_scores.append(test_f1)

# Compute the mean of the F1 scores across all folds
mean_train_f1 = np.mean(train_f1_scores)
mean_test_f1 = np.mean(test_f1_scores)

# Print the best hyperparameters and the mean F1 scores
print("Best Hyperparameters:")
print(best_params)
print("\nTraining F1 Score:")  # Change to F1 score
print(mean_train_f1)
print("\nTest F1 Score:")  # Change to F1 score
print(mean_test_f1)
# Out:
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# ...

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# Model evaluation on the test set
y_predicted = logistic_reg.predict(X_test)

cm = confusion_matrix(y_test, y_predicted)
print("Confusion Matrix:")
print(cm)

group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
group_counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cm.flatten() / np.sum(cm)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2, 2)
sns.heatmap(cm, annot=labels, fmt='', cmap='tab20b')

print("Accuracy Score on Test Set:")
print(accuracy_score(y_test, y_predicted))

print("Classification Report on Test Set:")
print(classification_report(y_test, y_predicted))
# Out:
# Confusion Matrix:
# [[5520  176]
#  [2268  269]]
# Accuracy Score on Test Set:
# 0.7031458763512692
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.71      0.97      0.82      5696
#            1       0.60      0.11      0.18      2537
#
#     accuracy                           0.70      8233
#    macro avg       0.66      0.54      0.50      8233
# weighted avg       0.68      0.70      0.62      8233

# %% [markdown]
# # Using Bayesian to search for optimal hyperparameters for a Logistic Regression Model + oversampling

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score  # Import the f1_score function
from sklearn.linear_model import LogisticRegression
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# Define the number of folds for cross-validation
n_folds = 5

# Initialize lists to store the estimated parameters and validation scores from each fold
params = []
params_intervals = []
train_f1_scores = []  # Change from train_auroc_scores to train_f1_scores
test_f1_scores = []   # Change from test_auroc_scores to test_f1_scores

# Perform cross-validation
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
for train_index, test_index in kf.split(df):
    # Reset the indices to ensure they are continuous
    train = df.iloc[train_index, :].reset_index(drop=True).copy()
    test = df.iloc[test_index, :].reset_index(drop=True).copy()

    response = 'y'  # the target is y
    predictors = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
       'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
       'day_of_week_encoded', 'education_encoded', 'month_encoded',
       'marital_divorced', 'marital_married', 'marital_single',
       'marital_unknown', 'job_admin.', 'job_blue-collar', 'job_entrepreneur',
       'job_housemaid', 'job_management', 'job_retired', 'job_self-employed',
       'job_services', 'job_student', 'job_technician', 'job_unemployed',
       'job_unknown', 'default_no', 'default_unknown', 'default_yes',
       'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
       'loan_unknown', 'loan_yes', 'contact_cellular', 'contact_telephone',
       'poutcome_failure', 'poutcome_nonexistent', 'poutcome_success']  # Replace with your predictor columns

    scaler = StandardScaler()

    X_train = scaler.fit_transform(train[predictors])
    X_test = scaler.transform(test[predictors])

    y_train = train[response]
    y_test = test[response]

    # Oversample the minority class in the training set
    oversampler = RandomOverSampler(random_state=42)
    X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train, y_train)

    # Define the logistic regression model
    logistic_reg = LogisticRegression()

    # Define the hyperparameter space for Bayesian optimization
    param_space = {
        'penalty': ['none', 'l2']
    }

    # Use Bayesian optimization to find the optimal hyperparameters
    opt = BayesSearchCV(logistic_reg, param_space, n_iter=50, cv=5)
    opt.fit(X_train_resampled, y_train_resampled)

    # Get the best hyperparameters
    best_params = opt.best_params_

    # Train the logistic regression model with the best hyperparameters
    logistic_reg2 = LogisticRegression(**best_params)
    logistic_reg2.fit(X_train_resampled, y_train_resampled)

    # Generate predictions for the training and test sets
    y_train_pred = logistic_reg2.predict(X_train)
    y_test_pred = logistic_reg2.predict(X_test)

    # Compute the F1 scores for training and test sets
    train_f1 = f1_score(y_train, y_train_pred)  # Use F1 score instead of AUROC
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1_scores.append(train_f1)
    test_f1_scores.append(test_f1)

# Compute the mean of the F1 scores across all folds
mean_train_f1 = np.mean(train_f1_scores)
mean_test_f1 = np.mean(test_f1_scores)

# Print the best hyperparameters and the mean F1 scores
print("Best Hyperparameters:")
print(best_params)
print("\nTraining F1 Score:")
print(mean_train_f1)
print("\nTest F1 Score:")
print(mean_test_f1)
# Out:
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# ...

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# Model evaluation on the test set
y_predicted = logistic_reg2.predict(X_test)

cm = confusion_matrix(y_test, y_predicted)
print("Confusion Matrix:")
print(cm)

group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
group_counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cm.flatten() / np.sum(cm)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2, 2)
sns.heatmap(cm, annot=labels, fmt='', cmap='tab20b')

print("Accuracy Score on Test Set:")
print(accuracy_score(y_test, y_predicted))

print("Classification Report on Test Set:")
print(classification_report(y_test, y_predicted))
# Out:
# Confusion Matrix:
# [[6306 1012]
#  [ 136  779]]
# Accuracy Score on Test Set:
# 0.8605611563221183
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.92      7318
#            1       0.43      0.85      0.58       915
#
#     accuracy                           0.86      8233
#    macro avg       0.71      0.86      0.75      8233
# weighted avg       0.92      0.86      0.88      8233

# %% [markdown]
# # coefficient magnitude plot

# %%
# Create a coefficient magnitude plot with feature names
coefficients = logistic_reg2.coef_[0]
abs_coefficients = np.abs(coefficients)
feature_names = predictors  # Use your list of feature names here

# Sort feature names and coefficients by absolute coefficient values
sorted_feature_names = [feature for _, feature in sorted(zip(abs_coefficients, feature_names), reverse=True)]
sorted_abs_coefficients = sorted(abs_coefficients, reverse=True)

plt.figure(figsize=(10, 6))
plt.barh(sorted_feature_names, sorted_abs_coefficients)
plt.xlabel('Absolute Coefficient Magnitude')
plt.title('Coefficient Magnitudes in Logistic Regression Model')
plt.grid(axis='x')
plt.show()

# %%
# Create a coefficient magnitude plot with feature names
coefficients = logistic_reg2.coef_[0]
feature_names = predictors  # Use your list of feature names here

# Sort feature names and coefficients by coefficient values
sorted_feature_names = [feature for _, feature in sorted(zip(coefficients, feature_names), key=lambda x: abs(x[0]), reverse=True)]
sorted_coefficients = sorted(coefficients, key=abs, reverse=True)

plt.figure(figsize=(10, 6))
plt.barh(sorted_feature_names, sorted_coefficients)
plt.xlabel('Coefficient Value')
plt.title('Coefficient Magnitudes in Logistic Regression Model')
plt.grid(axis='x')
plt.show()

# %% [markdown]
# # Train logistic regression with the most important features

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# Model evaluation on the test set
y_predicted = logistic_reg3.predict(X_test)

cm = confusion_matrix(y_test, y_predicted)
print("Confusion Matrix:")
print(cm)

group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
group_counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cm.flatten() / np.sum(cm)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2, 2)
sns.heatmap(cm, annot=labels, fmt='', cmap='tab20b')

print("Accuracy Score on Test Set:")
print(accuracy_score(y_test, y_predicted))

print("Classification Report on Test Set:")
print(classification_report(y_test, y_predicted))
# Out:
# Confusion Matrix:
# [[6306 1012]
#  [ 136  779]]
# Accuracy Score on Test Set:
# 0.8605611563221183
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.92      7318
#            1       0.43      0.85      0.58       915
#
#     accuracy                           0.86      8233
#    macro avg       0.71      0.86      0.75      8233
# weighted avg       0.92      0.86      0.88      8233

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score  # Import the f1_score function
from sklearn.linear_model import LogisticRegression
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# Define the number of folds for cross-validation
n_folds = 5

# Initialize lists to store the estimated parameters and validation scores from each fold
params = []
params_intervals = []
train_f1_scores = []  # Change from train_auroc_scores to train_f1_scores
test_f1_scores = []   # Change from test_auroc_scores to test_f1_scores

# Perform cross-validation
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
for train_index, test_index in kf.split(df):
    # Reset the indices to ensure they are continuous
    train = df.iloc[train_index, :].reset_index(drop=True).copy()
    test = df.iloc[test_index, :].reset_index(drop=True).copy()
    
    #column removed:'housing_no', 'housing_unknown', 'housing_yes','marital_unknown','job_housemaid','loan_unknown','job_management'

    response = 'y'  # the target is y
    predictors = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
       'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
        'education_encoded', 'month_encoded',
       'marital_divorced', 'marital_married', 'marital_single',
       'job_admin.', 'job_blue-collar', 'job_entrepreneur',
         'job_retired', 'job_self-employed',
       'job_services', 'job_student', 'job_technician', 'job_unemployed',
       'job_unknown', 'default_no', 'default_unknown', 'default_yes',
         'loan_no',
        'loan_yes', 'contact_cellular', 'contact_telephone',
       'poutcome_failure', 'poutcome_nonexistent', 'poutcome_success']  # Replace with your predictor columns

    scaler = StandardScaler()

    X_train = scaler.fit_transform(train[predictors])
    X_test = scaler.transform(test[predictors])

    y_train = train[response]
    y_test = test[response]

    # Oversample the minority class in the training set
    oversampler = RandomOverSampler(random_state=42)
    X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train, y_train)

    # Define the logistic regression model
    logistic_reg = LogisticRegression()

    # Define the hyperparameter space for Bayesian optimization
    param_space = {
        'penalty': ['none', 'l2']
    }

    # Use Bayesian optimization to find the optimal hyperparameters
    opt = BayesSearchCV(logistic_reg, param_space, n_iter=50, cv=5)
    opt.fit(X_train_resampled, y_train_resampled)

    # Get the best hyperparameters
    best_params = opt.best_params_

    # Train the logistic regression model with the best hyperparameters
    logistic_reg3 = LogisticRegression(**best_params)
    logistic_reg3.fit(X_train_resampled, y_train_resampled)

    # Generate predictions for the training and test sets
    y_train_pred = logistic_reg3.predict(X_train)
    y_test_pred = logistic_reg3.predict(X_test)

    # Compute the F1 scores for training and test sets
    train_f1 = f1_score(y_train, y_train_pred)  # Use F1 score instead of AUROC
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1_scores.append(train_f1)
    test_f1_scores.append(test_f1)

# Compute the mean of the F1 scores across all folds
mean_train_f1 = np.mean(train_f1_scores)
mean_test_f1 = np.mean(test_f1_scores)

# Print the best hyperparameters and the mean F1 scores
print("Best Hyperparameters:")
print(best_params)
print("\nTraining F1 Score:")
print(mean_train_f1)
print("\nTest F1 Score:")
print(mean_test_f1)
# Out:
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1183: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score  # Import the f1_score function
from sklearn.linear_model import LogisticRegression
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# Define the number of folds for cross-validation
n_folds = 5

# Initialize lists to store the estimated parameters and validation scores from each fold
params = []
params_intervals = []
train_f1_scores = []  # Change from train_auroc_scores to train_f1_scores
test_f1_scores = []   # Change from test_auroc_scores to test_f1_scores

# Perform cross-validation
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
for train_index, test_index in kf.split(df):
    # Reset the indices to ensure they are continuous
    train = df.iloc[train_index, :].reset_index(drop=True).copy()
    test = df.iloc[test_index, :].reset_index(drop=True).copy()
    
    #column removed:'housing_no', 'housing_unknown', 'housing_yes','marital_unknown','job_housemaid','loan_unknown','job_management'

    response = 'y'  # the target is y
    predictors = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
       'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
        'education_encoded', 'month_encoded',
       'marital_divorced', 'marital_married', 'marital_single',
       'job_admin.', 'job_blue-collar', 'job_entrepreneur',
         'job_retired', 'job_self-employed',
       'job_services', 'job_student', 'job_technician', 'job_unemployed',
       'job_unknown', 'default_no', 'default_unknown', 'default_yes',
         'loan_no',
        'loan_yes', 'contact_cellular', 'contact_telephone',
       'poutcome_failure', 'poutcome_nonexistent', 'poutcome_success']  # Replace with your predictor columns

    scaler = StandardScaler()

    X_train = scaler.fit_transform(train[predictors])
    X_test = scaler.transform(test[predictors])

    y_train = train[response]
    y_test = test[response]

    # Oversample the minority class in the training set
    oversampler = RandomOverSampler(random_state=42)
    X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train, y_train)

    # Define the logistic regression model
    logistic_reg = LogisticRegression()

    # Define the hyperparameter space for Bayesian optimization
    param_space = {
        'penalty': ['none', 'l2']
    }

    # Use Bayesian optimization to find the optimal hyperparameters
    opt = BayesSearchCV(logistic_reg, param_space, n_iter=50, cv=5)
    opt.fit(X_train_resampled, y_train_resampled)

    # Get the best hyperparameters
    best_params = opt.best_params_

    # Train the logistic regression model with the best hyperparameters
    logistic_reg3 = LogisticRegression(**best_params)
    logistic_reg3.fit(X_train_resampled, y_train_resampled)

    # Generate predictions for the training and test sets
    y_train_pred = logistic_reg3.predict(X_train)
    y_test_pred = logistic_reg3.predict(X_test)

    # Compute the F1 scores for training and test sets
    train_f1 = f1_score(y_train, y_train_pred)  # Use F1 score instead of AUROC
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1_scores.append(train_f1)
    test_f1_scores.append(test_f1)

# Compute the mean of the F1 scores across all folds
mean_train_f1 = np.mean(train_f1_scores)
mean_test_f1 = np.mean(test_f1_scores)

# Print the best hyperparameters and the mean F1 scores
print("Best Hyperparameters:")
print(best_params)
print("\nTraining F1 Score:")
print(mean_train_f1)
print("\nTest F1 Score:")
print(mean_test_f1)

# %% [markdown]
# # Using Bayesian to search for optimal hyperparameters for the knn Model

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
from sklearn.neighbors import KNeighborsClassifier
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler

# Define the number of folds for cross-validation
n_folds = 5

# Initialize lists to store the estimated parameters and validation scores from each fold
params = []
params_intervals = []
train_f1_scores = []
test_f1_scores = []

# Perform cross-validation
kf = KFold(n_splits=n_folds)
for train_index, test_index in kf.split(df):
    # Reset the indices to ensure they are continuous
    train = df.iloc[train_index, :].reset_index(drop=True).copy()
    test = df.iloc[test_index, :].reset_index(drop=True).copy()

    response = 'y'  # the target is y
    predictors = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
       'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
       'day_of_week_encoded', 'education_encoded', 'month_encoded',
       'marital_divorced', 'marital_married', 'marital_single',
       'marital_unknown', 'job_admin.', 'job_blue-collar', 'job_entrepreneur',
       'job_housemaid', 'job_management', 'job_retired', 'job_self-employed',
       'job_services', 'job_student', 'job_technician', 'job_unemployed',
       'job_unknown', 'default_no', 'default_unknown', 'default_yes',
       'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
       'loan_unknown', 'loan_yes', 'contact_cellular', 'contact_telephone',
       'poutcome_failure', 'poutcome_nonexistent', 'poutcome_success']  # Replace with your predictor columns

    scaler = StandardScaler()

    X_train = scaler.fit_transform(train[predictors])
    X_test = scaler.transform(test[predictors])

    y_train = train[response]
    y_test = test[response]

    # Define the KNN model
    knn = KNeighborsClassifier()

    # Define the hyperparameter space for Bayesian optimization
    param_space = {
        'n_neighbors': (1, 10),  # Adjust the range as needed

    }

    # Use Bayesian optimization to find the optimal hyperparameters
    opt = BayesSearchCV(knn, param_space, n_iter=50, cv=5)
    opt.fit(X_train, y_train)

    # Get the best hyperparameters
    best_params = opt.best_params_

    # Train the KNN model with the best hyperparameters
    knn = KNeighborsClassifier(**best_params)
    knn.fit(X_train, y_train)

    # Generate predictions for the training and test sets
    y_train_pred = knn.predict(X_train)
    y_test_pred = knn.predict(X_test)

    # Compute the F1 scores for training and test sets
    train_f1 = f1_score(y_train, y_train_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1_scores.append(train_f1)
    test_f1_scores.append(test_f1)

# Compute the mean of the F1 scores across all folds
mean_train_f1 = np.mean(train_f1_scores)
mean_test_f1 = np.mean(test_f1_scores)

# Print the best hyperparameters and the mean F1 scores
print("Best Hyperparameters:")
print(best_params)
print("\nTraining F1 Score:")
print(mean_train_f1)
print("\nTest F1 Score:")
print(mean_test_f1)
# Out:
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# ...

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# Model evaluation on the test set
y_predicted = knn.predict(X_test)

cm = confusion_matrix(y_test, y_predicted)
print("Confusion Matrix:")
print(cm)

group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
group_counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cm.flatten() / np.sum(cm)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2, 2)
sns.heatmap(cm, annot=labels, fmt='', cmap='tab20b')

print("Accuracy Score on Test Set:")
print(accuracy_score(y_test, y_predicted))

print("Classification Report on Test Set:")
print(classification_report(y_test, y_predicted))
# Out:
# Confusion Matrix:
# [[5508  188]
#  [2163  374]]
# Accuracy Score on Test Set:
# 0.7144418802380663
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.72      0.97      0.82      5696
#            1       0.67      0.15      0.24      2537
#
#     accuracy                           0.71      8233
#    macro avg       0.69      0.56      0.53      8233
# weighted avg       0.70      0.71      0.64      8233

# %% [markdown]
# # Using Bayesian to search for optimal hyperparameters for a knn Model + oversampling

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
from sklearn.neighbors import KNeighborsClassifier
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE

# Define the number of folds for cross-validation
n_folds = 5

# Initialize lists to store the estimated parameters and validation scores from each fold
params = []
params_intervals = []
train_f1_scores = []
test_f1_scores = []

# Perform cross-validation
kf = KFold(n_splits=n_folds)
for train_index, test_index in kf.split(df):
    # Reset the indices to ensure they are continuous
    train = df.iloc[train_index, :].reset_index(drop=True).copy()
    test = df.iloc[test_index, :].reset_index(drop=True).copy()

    response = 'y'  # the target is y
    predictors = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
       'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
       'day_of_week_encoded', 'education_encoded', 'month_encoded',
       'marital_divorced', 'marital_married', 'marital_single',
       'marital_unknown', 'job_admin.', 'job_blue-collar', 'job_entrepreneur',
       'job_housemaid', 'job_management', 'job_retired', 'job_self-employed',
       'job_services', 'job_student', 'job_technician', 'job_unemployed',
       'job_unknown', 'default_no', 'default_unknown', 'default_yes',
       'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
       'loan_unknown', 'loan_yes', 'contact_cellular', 'contact_telephone',
       'poutcome_failure', 'poutcome_nonexistent', 'poutcome_success']  # Replace with your predictor columns

    scaler = StandardScaler()

    X_train = scaler.fit_transform(train[predictors])
    X_test = scaler.transform(test[predictors])

    y_train = train[response]
    y_test = test[response]

    # Use SMOTE for oversampling the minority class
    smote = SMOTE(random_state=42)
    X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

    # Define the KNN model
    knn2 = KNeighborsClassifier()

    # Define the hyperparameter space for Bayesian optimization
    param_space = {
        'n_neighbors': (1, 10),  # Adjust the range as needed
    }

    # Use Bayesian optimization to find the optimal hyperparameters
    opt = BayesSearchCV(knn2, param_space, n_iter=50, cv=5)
    opt.fit(X_train_resampled, y_train_resampled)

    # Get the best hyperparameters
    best_params = opt.best_params_

    # Train the KNN model with the best hyperparameters
    knn2 = KNeighborsClassifier(**best_params)
    knn2.fit(X_train_resampled, y_train_resampled)

    # Generate predictions for the training and test sets using knn2
    y_train_pred = knn2.predict(X_train)
    y_test_pred = knn2.predict(X_test)

    # Compute the F1 scores for training and test sets
    train_f1 = f1_score(y_train, y_train_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1_scores.append(train_f1)
    test_f1_scores.append(test_f1)

# Compute the mean of the F1 scores across all folds
mean_train_f1 = np.mean(train_f1_scores)
mean_test_f1 = np.mean(test_f1_scores)

# Print the best hyperparameters and the mean F1 scores
print("Best Hyperparameters:")
print(best_params)
print("\nTraining F1 Score:")
print(mean_train_f1)
print("\nTest F1 Score:")
print(mean_test_f1)
# Out:
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# ...

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# Model evaluation on the test set
y_predicted = knn2.predict(X_test)

cm = confusion_matrix(y_test, y_predicted)
print("Confusion Matrix:")
print(cm)

group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
group_counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cm.flatten() / np.sum(cm)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2, 2)
sns.heatmap(cm, annot=labels, fmt='', cmap='tab20b')

print("Accuracy Score on Test Set:")
print(accuracy_score(y_test, y_predicted))

print("Classification Report on Test Set:")
print(classification_report(y_test, y_predicted))
# Out:
# Confusion Matrix:
# [[4972  724]
#  [1804  733]]
# Accuracy Score on Test Set:
# 0.6929430341309365
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.73      0.87      0.80      5696
#            1       0.50      0.29      0.37      2537
#
#     accuracy                           0.69      8233
#    macro avg       0.62      0.58      0.58      8233
# weighted avg       0.66      0.69      0.66      8233

# %% [markdown]
# # Using bayesian search to search for optimal hyperparameters for a GBM Model

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
from sklearn.ensemble import GradientBoostingClassifier
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler

# Define the number of folds for cross-validation
n_folds = 5

# Initialize lists to store the estimated parameters and validation scores from each fold
params = []
train_f1_scores = []
test_f1_scores = []

# Perform cross-validation
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
for train_index, test_index in kf.split(df):
    # Reset the indices to ensure they are continuous
    train = df.iloc[train_index, :].reset_index(drop=True).copy()
    test = df.iloc[test_index, :].reset_index(drop=True).copy()

    response = 'y'  # the target is y
    predictors = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
       'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
       'day_of_week_encoded', 'education_encoded', 'month_encoded',
       'marital_divorced', 'marital_married', 'marital_single',
       'marital_unknown', 'job_admin.', 'job_blue-collar', 'job_entrepreneur',
       'job_housemaid', 'job_management', 'job_retired', 'job_self-employed',
       'job_services', 'job_student', 'job_technician', 'job_unemployed',
       'job_unknown', 'default_no', 'default_unknown', 'default_yes',
       'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
       'loan_unknown', 'loan_yes', 'contact_cellular', 'contact_telephone',
       'poutcome_failure', 'poutcome_nonexistent', 'poutcome_success']  # Replace with your predictor columns

    scaler = StandardScaler()

    X_train = scaler.fit_transform(train[predictors])
    X_test = scaler.transform(test[predictors])

    y_train = train[response]
    y_test = test[response]

    # Define the GBM model
    gbm = GradientBoostingClassifier()

    # Define the hyperparameter space for Bayesian optimization
    param_space = {
        'n_estimators': (10, 100),  # Define a range for n_estimators
    }

    # Use Bayesian optimization to find the optimal hyperparameters with F1 score as the scoring metric
    bayes_search = BayesSearchCV(gbm, param_space, cv=5, scoring='f1', n_iter=32)
    bayes_search.fit(X_train, y_train)

    # Get the best hyperparameters
    best_params = bayes_search.best_params_

    # Train the GBM model with the best hyperparameters
    gbm = GradientBoostingClassifier(**best_params)
    gbm.fit(X_train, y_train)

    # Generate predictions for the training and test sets
    y_train_pred = gbm.predict(X_train)
    y_test_pred = gbm.predict(X_test)

    # Compute the F1 scores for training and test sets
    train_f1 = f1_score(y_train, y_train_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1_scores.append(train_f1)
    test_f1_scores.append(test_f1)

# Compute the mean of the F1 scores across all folds
mean_train_f1 = np.mean(train_f1_scores)
mean_test_f1 = np.mean(test_f1_scores)

# Print the best hyperparameters and the mean F1 scores
print("Best Hyperparameters:")
print(best_params)
print("\nTraining F1 Score:")
print(mean_train_f1)
print("\nTest F1 Score:")
print(mean_test_f1)
# Out:
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# ...

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# Model evaluation on the test set
y_predicted = gbm.predict(X_test)

cm = confusion_matrix(y_test, y_predicted)
print("Confusion Matrix:")
print(cm)

group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
group_counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cm.flatten() / np.sum(cm)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2, 2)
sns.heatmap(cm, annot=labels, fmt='', cmap='tab20b')

print("Accuracy Score on Test Set:")
print(accuracy_score(y_test, y_predicted))

print("Classification Report on Test Set:")
print(classification_report(y_test, y_predicted))
# Out:
# Confusion Matrix:
# [[7117  201]
#  [ 461  454]]
# Accuracy Score on Test Set:
# 0.9195918863111867
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96      7318
#            1       0.69      0.50      0.58       915
#
#     accuracy                           0.92      8233
#    macro avg       0.82      0.73      0.77      8233
# weighted avg       0.91      0.92      0.91      8233

# %%
# Get feature importances
feature_importances = gbm.feature_importances_

# Create a DataFrame to associate feature names with their importances
feature_importance_df = pd.DataFrame({'Feature': predictors, 'Importance': feature_importances})

# Sort the DataFrame by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Create a bar plot to visualize feature importance
plt.figure(figsize=(12, 8))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Feature Importance Plot')
plt.show()

# %% [markdown]
# # Use bayesian search +oversampling for GBM

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
from sklearn.ensemble import GradientBoostingClassifier
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# Define the number of folds for cross-validation
n_folds = 5

# Initialize lists to store the estimated parameters and validation scores from each fold
params = []
train_f1_scores = []
test_f1_scores = []

# Perform cross-validation
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
for train_index, test_index in kf.split(df):
    # Reset the indices to ensure they are continuous
    train = df.iloc[train_index, :].reset_index(drop=True).copy()
    test = df.iloc[test_index, :].reset_index(drop=True).copy()

    response = 'y'  # the target is y
    predictors = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
       'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
       'day_of_week_encoded', 'education_encoded', 'month_encoded',
       'marital_divorced', 'marital_married', 'marital_single',
       'marital_unknown', 'job_admin.', 'job_blue-collar', 'job_entrepreneur',
       'job_housemaid', 'job_management', 'job_retired', 'job_self-employed',
       'job_services', 'job_student', 'job_technician', 'job_unemployed',
       'job_unknown', 'default_no', 'default_unknown', 'default_yes',
       'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
       'loan_unknown', 'loan_yes', 'contact_cellular', 'contact_telephone',
       'poutcome_failure', 'poutcome_nonexistent', 'poutcome_success']  # Replace with your predictor columns

    scaler = StandardScaler()

    X_train = scaler.fit_transform(train[predictors])
    X_test = scaler.transform(test[predictors])

    y_train = train[response]
    y_test = test[response]

    # Oversample the minority class in the training set
    oversampler = RandomOverSampler(random_state=42)
    X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train, y_train)

    # Define the GBM model
    gbm = GradientBoostingClassifier()

    # Define the hyperparameter space for Bayesian optimization
    param_space = {
        'n_estimators': (10, 100),  # Define a range for n_estimators
    }

    # Use Bayesian optimization to find the optimal hyperparameters with F1 score as the scoring metric
    bayes_search = BayesSearchCV(gbm, param_space, cv=5, scoring='f1', n_iter=32)
    bayes_search.fit(X_train_resampled, y_train_resampled)

    # Get the best hyperparameters
    best_params = bayes_search.best_params_

    # Train the GBM model with the best hyperparameters
    gbm2 = GradientBoostingClassifier(**best_params)
    gbm2.fit(X_train_resampled, y_train_resampled)

    # Generate predictions for the training and test sets
    y_train_pred = gbm2.predict(X_train)
    y_test_pred = gbm2.predict(X_test)

    # Compute the F1 scores for training and test sets
    train_f1 = f1_score(y_train, y_train_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1_scores.append(train_f1)
    test_f1_scores.append(test_f1)

# Compute the mean of the F1 scores across all folds
mean_train_f1 = np.mean(train_f1_scores)
mean_test_f1 = np.mean(test_f1_scores)

# Print the best hyperparameters and the mean F1 scores
print("Best Hyperparameters:")
print(best_params)
print("\nTraining F1 Score:")
print(mean_train_f1)
print("\nTest F1 Score:")
print(mean_test_f1)
# Out:
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# ...

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# Model evaluation on the test set
y_predicted = gbm2.predict(X_test)

cm = confusion_matrix(y_test, y_predicted)
print("Confusion Matrix:")
print(cm)

group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
group_counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cm.flatten() / np.sum(cm)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2, 2)
sns.heatmap(cm, annot=labels, fmt='', cmap='tab20b')

print("Accuracy Score on Test Set:")
print(accuracy_score(y_test, y_predicted))

print("Classification Report on Test Set:")
print(classification_report(y_test, y_predicted))
# Out:
# Confusion Matrix:
# [[6079 1239]
#  [  85  830]]
# Accuracy Score on Test Set:
# 0.8391837726223734
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.99      0.83      0.90      7318
#            1       0.40      0.91      0.56       915
#
#     accuracy                           0.84      8233
#    macro avg       0.69      0.87      0.73      8233
# weighted avg       0.92      0.84      0.86      8233

# %% [markdown]
# # Feature importance

# %%
# Get feature importances
feature_importances = gbm2.feature_importances_

# Create a DataFrame to associate feature names with their importances
feature_importance_df = pd.DataFrame({'Feature': predictors, 'Importance': feature_importances})

# Sort the DataFrame by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Create a bar plot to visualize feature importance
plt.figure(figsize=(12, 8))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Feature Importance Plot')
plt.show()

# %% [markdown]
# # Use bayesian with the most important features +oversampling for GBM

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
from sklearn.ensemble import GradientBoostingClassifier
from skopt import BayesSearchCV  # Import BayesSearchCV
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# Define the number of folds for cross-validation
n_folds = 5

# Initialize lists to store the estimated parameters and validation scores from each fold
params = []
train_f1_scores = []
test_f1_scores = []

# Perform cross-validation
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
for train_index, test_index in kf.split(df):
    # Reset the indices to ensure they are continuous
    train = df.iloc[train_index, :].reset_index(drop=True).copy()
    test = df.iloc[test_index, :].reset_index(drop=True).copy()

    response = 'y'  # the target is y
    predictors = [ 'poutcome_success','euribor3m','cons.price.idx', 'cons.conf.idx',
                  'month_encoded','emp.var.rate', 'nr.employed','duration','pdays']  # Replace with your predictor columns
    
    scaler = StandardScaler()

    X_train = scaler.fit_transform(train[predictors])
    X_test = scaler.transform(test[predictors])

    y_train = train[response]
    y_test = test[response]

    # Oversample the minority class in the training set
    oversampler = RandomOverSampler(random_state=42)
    X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train, y_train)

    # Define the GBM model
    gbm = GradientBoostingClassifier()

    # Define the hyperparameter space for Bayesian optimization
    param_space = {
        'n_estimators': (10, 25),  # Define the search range
        'max_depth': (3, 20)  # Define the search range
    }

    # Use Bayesian optimization to find the optimal hyperparameters
    opt = BayesSearchCV(gbm, param_space, n_iter=50, cv=5, scoring='f1')
    opt.fit(X_train_resampled, y_train_resampled)

    # Get the best hyperparameters
    best_params = opt.best_params_

    # Train the GBM model with the best hyperparameters
    gbm3 = GradientBoostingClassifier(**best_params)
    gbm3.fit(X_train_resampled, y_train_resampled)

    # Generate predictions for the training and test sets
    y_train_pred = gbm3.predict(X_train)
    y_test_pred = gbm3.predict(X_test)

    # Compute the F1 scores for training and test sets
    train_f1 = f1_score(y_train, y_train_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1_scores.append(train_f1)
    test_f1_scores.append(test_f1)

# Compute the mean of the F1 scores across all folds
mean_train_f1 = np.mean(train_f1_scores)
mean_test_f1 = np.mean(test_f1_scores)

# Print the best hyperparameters and the mean F1 scores
print("Best Hyperparameters:")
print(best_params)
print("\nTraining F1 Score:")
print(mean_train_f1)
print("\nTest F1 Score:")
print(mean_test_f1)
# Out:
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# ...

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# Model evaluation on the test set
y_predicted = gbm3.predict(X_test)

cm = confusion_matrix(y_test, y_predicted)
print("Confusion Matrix:")
print(cm)

group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
group_counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cm.flatten() / np.sum(cm)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2, 2)
sns.heatmap(cm, annot=labels, fmt='', cmap='tab20b')

print("Accuracy Score on Test Set:")
print(accuracy_score(y_test, y_predicted))

print("Classification Report on Test Set:")
print(classification_report(y_test, y_predicted))
# Out:
# Confusion Matrix:
# [[6080 1238]
#  [  85  830]]
# Accuracy Score on Test Set:
# 0.8393052350297583
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.99      0.83      0.90      7318
#            1       0.40      0.91      0.56       915
#
#     accuracy                           0.84      8233
#    macro avg       0.69      0.87      0.73      8233
# weighted avg       0.92      0.84      0.86      8233

# %% [markdown]
# # Use bayesian model with gbm without over sammpling

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
from sklearn.ensemble import GradientBoostingClassifier
from skopt import BayesSearchCV
from sklearn.preprocessing import StandardScaler

# Define the number of folds for cross-validation
n_folds = 5

# Initialize lists to store the estimated parameters and validation scores from each fold
params = []
train_f1_scores = []
test_f1_scores = []

# Perform cross-validation
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
for train_index, test_index in kf.split(df):
    # Reset the indices to ensure they are continuous
    train = df.iloc[train_index, :].reset_index(drop=True).copy()
    test = df.iloc[test_index, :].reset_index(drop=True).copy()

    response = 'y'  # the target is y
    predictors = [ 'poutcome_success','euribor3m','cons.price.idx', 'cons.conf.idx',
                  'month_encoded','emp.var.rate', 'nr.employed','duration','pdays']  # Replace with your predictor columns
    
    scaler = StandardScaler()

    X_train = scaler.fit_transform(train[predictors])
    X_test = scaler.transform(test[predictors])

    y_train = train[response]
    y_test = test[response]

    # Define the GBM model
    gbm = GradientBoostingClassifier()

    # Define the hyperparameter space for Bayesian optimization
    param_space = {
        'n_estimators': (10, 25),  # Define the search range
        'max_depth': (20,100)  # Define the search range
    }

    # Use Bayesian optimization to find the optimal hyperparameters
    opt = BayesSearchCV(gbm, param_space, n_iter=50, cv=5, scoring='f1')
    opt.fit(X_train, y_train)  # No oversampling

    # Get the best hyperparameters
    best_params = opt.best_params_

    # Train the GBM model with the best hyperparameters
    gbm4 = GradientBoostingClassifier(**best_params)
    gbm4.fit(X_train, y_train)

    # Generate predictions for the training and test sets
    y_train_pred = gbm4.predict(X_train)
    y_test_pred = gbm4.predict(X_test)

    # Compute the F1 scores for training and test sets
    train_f1 = f1_score(y_train, y_train_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    train_f1_scores.append(train_f1)
    test_f1_scores.append(test_f1)

# Compute the mean of the F1 scores across all folds
mean_train_f1 = np.mean(train_f1_scores)
mean_test_f1 = np.mean(test_f1_scores)

# Print the best hyperparameters and the mean F1 scores
print("Best Hyperparameters:")
print(best_params)
print("\nTraining F1 Score:")
print(mean_train_f1)
print("\nTest F1 Score:")
print(mean_test_f1)
# Out:
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/yasamanmohammadi/.pyenv/versions/3.9.13/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# ...
